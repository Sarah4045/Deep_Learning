# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarah4045/Deep_Learning/blob/main/DNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
data = pd.read_csv('/content/Airline_Delay_Cause.csv')

# %%
data
# Out:
#         year  month carrier          carrier_name airport  \
# 0       2022      5      9E     Endeavor Air Inc.     ABE
# 1       2022      5      9E     Endeavor Air Inc.     ABY
# 2       2022      5      9E     Endeavor Air Inc.     ACK
# 3       2022      5      9E     Endeavor Air Inc.     AEX
# 4       2022      5      9E     Endeavor Air Inc.     AGS
# ...      ...    ...     ...                   ...     ...
# 318012  2003      6      DL  Delta Air Lines Inc.     SEA
# 318013  2003      6      DL  Delta Air Lines Inc.     SFO
# 318014  2003      6      DL  Delta Air Lines Inc.     SJC
# 318015  2003      6      DL  Delta Air Lines Inc.     SJU
# 318016  2003      6      DL  Delta Air Lines Inc.     SLC
#
#                                              airport_name  arr_flights  \
# 0       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        136.0
# 1                  Albany, GA: Southwest Georgia Regional         91.0
# 2                       Nantucket, MA: Nantucket Memorial         19.0
# 3                Alexandria, LA: Alexandria International         88.0
# 4             Augusta, GA: Augusta Regional at Bush Field        181.0
# ...                                                   ...          ...
# 318012          Seattle, WA: Seattle/Tacoma International        480.0
# 318013     San Francisco, CA: San Francisco International        505.0
# 318014  San Jose, CA: Norman Y. Mineta San Jose Intern...        146.0
# 318015       San Juan, PR: Luis Munoz Marin International         95.0
# 318016   Salt Lake City, UT: Salt Lake City International       3466.0
#
#         arr_del15  carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  \
# 0             7.0        5.95        0.00  ...          0.0              1.00
# 1            16.0        7.38        0.00  ...          0.0              6.09
# 2             2.0        0.13        0.00  ...          0.0              0.88
# 3            14.0        7.26        0.76  ...          0.0              1.64
# 4            19.0       13.84        0.00  ...          0.0              2.09
# ...           ...         ...         ...  ...          ...               ...
# 318012       84.0       25.69        3.09  ...          0.0             21.26
# 318013      111.0       21.78        2.24  ...          0.0             13.17
# 318014       36.0        6.99        0.00  ...          0.0              2.15
# 318015       13.0        3.66        0.00  ...          0.0              1.42
# 318016      454.0      121.15        7.61  ...          1.0            102.33
#
#         arr_cancelled  arr_diverted  arr_delay  carrier_delay  weather_delay  \
# 0                 0.0           0.0      255.0          222.0            0.0
# 1                 0.0           0.0      884.0          351.0            0.0
# 2                 1.0           0.0      138.0            4.0            0.0
# 3                 0.0           0.0      947.0          585.0           35.0
# 4                 0.0           0.0      808.0          662.0            0.0
# ...               ...           ...        ...            ...            ...
# 318012            0.0           0.0     3744.0          978.0          164.0
# 318013            3.0           0.0     4284.0         1376.0          138.0
# 318014            0.0           0.0      896.0          205.0            0.0
# 318015            0.0           0.0      367.0          120.0            0.0
# 318016            9.0           0.0    16853.0         5384.0          306.0
#
#         nas_delay  security_delay  late_aircraft_delay
# 0             4.0             0.0                 29.0
# 1            81.0             0.0                452.0
# 2           106.0             0.0                 28.0
# 3           125.0             0.0                202.0
# 4            87.0             0.0                 59.0
# ...           ...             ...                  ...
# 318012     1023.0             0.0               1579.0
# 318013     2132.0             0.0                638.0
# 318014      607.0             0.0                 84.0
# 318015      210.0             0.0                 37.0
# 318016     5686.0            28.0               5449.0
#
# [318017 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318017 entries, 0 to 318016
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   year                 318017 non-null  int64
#  1   month                318017 non-null  int64
#  2   carrier              318013 non-null  object
#  3   carrier_name         318013 non-null  object
#  4   airport              318014 non-null  object
#  5   airport_name         318017 non-null  object
#  6   arr_flights          317524 non-null  float64
#  7   arr_del15            317285 non-null  float64
#  8   carrier_ct           317525 non-null  float64
#  9   weather_ct           317523 non-null  float64
#  10  nas_ct               317529 non-null  float64
#  11  security_ct          317529 non-null  float64
#  12  late_aircraft_ct     317529 non-null  float64
#  13  arr_cancelled        317529 non-null  float64
#  14  arr_diverted         317527 non-null  float64
#  15  arr_delay            317523 non-null  float64
#  16  carrier_delay        317525 non-null  float64
#  17  weather_delay        317529 non-null  float64
#  18  nas_delay            317529 non-null  float64
#  19  security_delay       317527 non-null  float64
#  20  late_aircraft_delay  317529 non-null  float64
# dtypes: float64(15), int64(2), object(4)
# memory usage: 51.0+ MB

# %%
data = data.drop(['carrier','carrier_name','airport','airport_name'],axis=1)
data
# Out:
#         year  month  arr_flights  arr_del15  carrier_ct  weather_ct  nas_ct  \
# 0       2022      5        136.0        7.0        5.95        0.00    0.05
# 1       2022      5         91.0       16.0        7.38        0.00    2.54
# 2       2022      5         19.0        2.0        0.13        0.00    1.00
# 3       2022      5         88.0       14.0        7.26        0.76    4.35
# 4       2022      5        181.0       19.0       13.84        0.00    3.07
# ...      ...    ...          ...        ...         ...         ...     ...
# 318012  2003      6        480.0       84.0       25.69        3.09   33.96
# 318013  2003      6        505.0      111.0       21.78        2.24   73.81
# 318014  2003      6        146.0       36.0        6.99        0.00   26.85
# 318015  2003      6         95.0       13.0        3.66        0.00    7.92
# 318016  2003      6       3466.0      454.0      121.15        7.61  221.91
#
#         security_ct  late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 0               0.0              1.00            0.0           0.0      255.0
# 1               0.0              6.09            0.0           0.0      884.0
# 2               0.0              0.88            1.0           0.0      138.0
# 3               0.0              1.64            0.0           0.0      947.0
# 4               0.0              2.09            0.0           0.0      808.0
# ...             ...               ...            ...           ...        ...
# 318012          0.0             21.26            0.0           0.0     3744.0
# 318013          0.0             13.17            3.0           0.0     4284.0
# 318014          0.0              2.15            0.0           0.0      896.0
# 318015          0.0              1.42            0.0           0.0      367.0
# 318016          1.0            102.33            9.0           0.0    16853.0
#
#         carrier_delay  weather_delay  nas_delay  security_delay  \
# 0               222.0            0.0        4.0             0.0
# 1               351.0            0.0       81.0             0.0
# 2                 4.0            0.0      106.0             0.0
# 3               585.0           35.0      125.0             0.0
# 4               662.0            0.0       87.0             0.0
# ...               ...            ...        ...             ...
# 318012          978.0          164.0     1023.0             0.0
# 318013         1376.0          138.0     2132.0             0.0
# 318014          205.0            0.0      607.0             0.0
# 318015          120.0            0.0      210.0             0.0
# 318016         5384.0          306.0     5686.0            28.0
#
#         late_aircraft_delay
# 0                      29.0
# 1                     452.0
# 2                      28.0
# 3                     202.0
# 4                      59.0
# ...                     ...
# 318012               1579.0
# 318013                638.0
# 318014                 84.0
# 318015                 37.0
# 318016               5449.0
#
# [318017 rows x 17 columns]

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 317268 entries, 0 to 318016
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   year                 317268 non-null  int64
#  1   month                317268 non-null  int64
#  2   arr_flights          317268 non-null  float64
#  3   arr_del15            317268 non-null  float64
#  4   carrier_ct           317268 non-null  float64
#  5   weather_ct           317268 non-null  float64
#  6   nas_ct               317268 non-null  float64
#  7   security_ct          317268 non-null  float64
#  8   late_aircraft_ct     317268 non-null  float64
#  9   arr_cancelled        317268 non-null  float64
#  10  arr_diverted         317268 non-null  float64
#  11  arr_delay            317268 non-null  float64
#  12  carrier_delay        317268 non-null  float64
#  13  weather_delay        317268 non-null  float64
#  14  nas_delay            317268 non-null  float64
#  15  security_delay       317268 non-null  float64
#  16  late_aircraft_delay  317268 non-null  float64
# dtypes: float64(15), int64(2)
# memory usage: 43.6 MB

# %%
data['weather_delay'].min(),data['weather_delay'].max()
# Out:
# (0.0, 57707.0)

# %%
data['WDCase'] = data['weather_delay'].apply(lambda x : 1 if x >100 else 0)

# %%
data['WDCase'].value_counts()
# Out:
# WDCase
# 0    215116
# 1    102152
# Name: count, dtype: int64

# %%
data
# Out:
#         year  month  arr_flights  arr_del15  carrier_ct  weather_ct  nas_ct  \
# 0       2022      5        136.0        7.0        5.95        0.00    0.05
# 1       2022      5         91.0       16.0        7.38        0.00    2.54
# 2       2022      5         19.0        2.0        0.13        0.00    1.00
# 3       2022      5         88.0       14.0        7.26        0.76    4.35
# 4       2022      5        181.0       19.0       13.84        0.00    3.07
# ...      ...    ...          ...        ...         ...         ...     ...
# 318012  2003      6        480.0       84.0       25.69        3.09   33.96
# 318013  2003      6        505.0      111.0       21.78        2.24   73.81
# 318014  2003      6        146.0       36.0        6.99        0.00   26.85
# 318015  2003      6         95.0       13.0        3.66        0.00    7.92
# 318016  2003      6       3466.0      454.0      121.15        7.61  221.91
#
#         security_ct  late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 0               0.0              1.00            0.0           0.0      255.0
# 1               0.0              6.09            0.0           0.0      884.0
# 2               0.0              0.88            1.0           0.0      138.0
# 3               0.0              1.64            0.0           0.0      947.0
# 4               0.0              2.09            0.0           0.0      808.0
# ...             ...               ...            ...           ...        ...
# 318012          0.0             21.26            0.0           0.0     3744.0
# 318013          0.0             13.17            3.0           0.0     4284.0
# 318014          0.0              2.15            0.0           0.0      896.0
# 318015          0.0              1.42            0.0           0.0      367.0
# 318016          1.0            102.33            9.0           0.0    16853.0
#
#         carrier_delay  weather_delay  nas_delay  security_delay  \
# 0               222.0            0.0        4.0             0.0
# 1               351.0            0.0       81.0             0.0
# 2                 4.0            0.0      106.0             0.0
# 3               585.0           35.0      125.0             0.0
# 4               662.0            0.0       87.0             0.0
# ...               ...            ...        ...             ...
# 318012          978.0          164.0     1023.0             0.0
# 318013         1376.0          138.0     2132.0             0.0
# 318014          205.0            0.0      607.0             0.0
# 318015          120.0            0.0      210.0             0.0
# 318016         5384.0          306.0     5686.0            28.0
#
#         late_aircraft_delay  WDCase
# 0                      29.0       0
# 1                     452.0       0
# 2                      28.0       0
# 3                     202.0       0
# 4                      59.0       0
# ...                     ...     ...
# 318012               1579.0       1
# 318013                638.0       1
# 318014                 84.0       0
# 318015                 37.0       0
# 318016               5449.0       1
#
# [317268 rows x 18 columns]

# %%
X = data.drop(['WDCase'],axis = 1)
y =data['WDCase']

# %%
X
# Out:
#         year  month  arr_flights  arr_del15  carrier_ct  weather_ct  nas_ct  \
# 0       2022      5        136.0        7.0        5.95        0.00    0.05
# 1       2022      5         91.0       16.0        7.38        0.00    2.54
# 2       2022      5         19.0        2.0        0.13        0.00    1.00
# 3       2022      5         88.0       14.0        7.26        0.76    4.35
# 4       2022      5        181.0       19.0       13.84        0.00    3.07
# ...      ...    ...          ...        ...         ...         ...     ...
# 318012  2003      6        480.0       84.0       25.69        3.09   33.96
# 318013  2003      6        505.0      111.0       21.78        2.24   73.81
# 318014  2003      6        146.0       36.0        6.99        0.00   26.85
# 318015  2003      6         95.0       13.0        3.66        0.00    7.92
# 318016  2003      6       3466.0      454.0      121.15        7.61  221.91
#
#         security_ct  late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 0               0.0              1.00            0.0           0.0      255.0
# 1               0.0              6.09            0.0           0.0      884.0
# 2               0.0              0.88            1.0           0.0      138.0
# 3               0.0              1.64            0.0           0.0      947.0
# 4               0.0              2.09            0.0           0.0      808.0
# ...             ...               ...            ...           ...        ...
# 318012          0.0             21.26            0.0           0.0     3744.0
# 318013          0.0             13.17            3.0           0.0     4284.0
# 318014          0.0              2.15            0.0           0.0      896.0
# 318015          0.0              1.42            0.0           0.0      367.0
# 318016          1.0            102.33            9.0           0.0    16853.0
#
#         carrier_delay  weather_delay  nas_delay  security_delay  \
# 0               222.0            0.0        4.0             0.0
# 1               351.0            0.0       81.0             0.0
# 2                 4.0            0.0      106.0             0.0
# 3               585.0           35.0      125.0             0.0
# 4               662.0            0.0       87.0             0.0
# ...               ...            ...        ...             ...
# 318012          978.0          164.0     1023.0             0.0
# 318013         1376.0          138.0     2132.0             0.0
# 318014          205.0            0.0      607.0             0.0
# 318015          120.0            0.0      210.0             0.0
# 318016         5384.0          306.0     5686.0            28.0
#
#         late_aircraft_delay
# 0                      29.0
# 1                     452.0
# 2                      28.0
# 3                     202.0
# 4                      59.0
# ...                     ...
# 318012               1579.0
# 318013                638.0
# 318014                 84.0
# 318015                 37.0
# 318016               5449.0
#
# [317268 rows x 17 columns]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 318012    1
# 318013    1
# 318014    0
# 318015    0
# 318016    1
# Name: WDCase, Length: 317268, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=44, shuffle =True)

print('X_train shape is ' , X_train.shape)
print('X_test shape is ' , X_test.shape)
print('y_train shape is ' , y_train.shape)
print('y_test shape is ' , y_test.shape)
# Out:
# X_train shape is  (237951, 17)
# X_test shape is  (79317, 17)
# y_train shape is  (237951,)
# y_test shape is  (79317,)

# %%
import tensorflow as tf
import keras

# %%
KerasModel = keras.models.Sequential([
                # keras.layers.Input(shape=(17)),
            keras.layers.Dense(8,  activation = 'tanh'),
            # keras.layers.Dropout(0.1),
            keras.layers.Dense(128, activation = 'sigmoid'),
            # keras.layers.Dropout(0.3),
            keras.layers.Dense(64, activation = 'tanh'),
            keras.layers.Dense(32, activation = 'tanh'),
            keras.layers.Dropout(0.2),
            keras.layers.Dense(1, activation = 'sigmoid')
            ])

# %%
import tensorflow as tf

MyOptimizer = tf.keras.optimizers.AdamW(
    learning_rate=0.001,
    weight_decay=0.004,
    beta_1=0.9,
    beta_2=0.999
)

# %%
KerasModel.compile(optimizer =MyOptimizer,loss='binary_crossentropy',metrics=['accuracy']) # matrix

# %%
history = KerasModel.fit(X_train,y_train,
                         validation_data=(X_test,y_test),
                         epochs=100,
                         batch_size=10000,
                         verbose=1,
                         callbacks=[tf.keras.callbacks.EarlyStopping(
                                            patience=10,
                                            monitor='val_accuracy',#"val_loss",
                                            restore_best_weights=True)])
# Out:
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.5858 - loss: 0.7109 - val_accuracy: 0.6773 - val_loss: 0.6027
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.6785 - loss: 0.5939 - val_accuracy: 0.6773 - val_loss: 0.5167
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.7658 - loss: 0.4866 - val_accuracy: 0.8025 - val_loss: 0.4105
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.8048 - loss: 0.4026 - val_accuracy: 0.8173 - val_loss: 0.3844
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.8156 - loss: 0.3769 - val_accuracy: 0.8235 - val_loss: 0.3571
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8218 - loss: 0.3490 - val_accuracy: 0.8384 - val_loss: 0.3273
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.8498 - loss: 0.3188 - val_accuracy: 0.8630 - val_loss: 0.2934
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8658 - loss: 0.2879 - val_accuracy: 0.8683 - val_loss: 0.2653
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8760 - loss: 0.2591 - val_accuracy: 0.8897 - val_loss: 0.2331
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.8969 - loss: 0.2246 - val_accuracy: 0.9121 - val_loss: 0.1998
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9191 - loss: 0.1906 - val_accuracy: 0.9355 - val_loss: 0.1617
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9397 - loss: 0.1576 - val_accuracy: 0.9515 - val_loss: 0.1268
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9596 - loss: 0.1126 - val_accuracy: 0.9810 - val_loss: 0.0714
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9845 - loss: 0.0670 - val_accuracy: 0.9846 - val_loss: 0.0682
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9852 - loss: 0.0683 - val_accuracy: 0.9852 - val_loss: 0.0664
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.
# Out:
#         year  month  arr_flights  arr_del15  carrier_ct  weather_ct  nas_ct  \
# 256596  2007      1        213.0       64.0       16.33        3.44   15.06
# 6930    2022      1        617.0       82.0       29.69        2.04   26.88
# 125951  2014     11         62.0        8.0        3.00        0.00    2.09
# 87817   2017     10         82.0        9.0        6.00        1.20    1.00
# 42037   2020      3        168.0       12.0        6.65        2.00    1.04
# ...      ...    ...          ...        ...         ...         ...     ...
# 132929  2014      5       2410.0      637.0      222.01        9.35   56.16
# 251541  2007      4         42.0        8.0        5.83        0.00    1.50
# 84057   2018      1         80.0       12.0        3.48        3.92    0.12
# 32889   2020     10        356.0       23.0        8.12        0.00   10.33
# 269836  2006      4       1075.0      181.0       56.35        1.40   82.43
#
#         security_ct  late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 256596         0.00             29.17           13.0           0.0     3840.0
# 6930           0.30             23.08           27.0           1.0     5410.0
# 125951         0.00              2.91            0.0           0.0      609.0
# 87817          0.00              0.80            0.0           0.0      260.0
# 42037          0.00              2.31           19.0           0.0      558.0
# ...             ...               ...            ...           ...        ...
# 132929         0.85            348.62           13.0           0.0    34346.0
# 251541         0.00              0.67            1.0           0.0      306.0
# 84057          0.00              4.48            2.0           0.0     1060.0
# 32889          0.00              4.56            0.0           2.0      989.0
# 269836         0.77             40.05            4.0           2.0     7544.0
#
#         carrier_delay  weather_delay  nas_delay  security_delay  \
# 256596          912.0          292.0      720.0             0.0
# 6930           2471.0          157.0     1095.0            15.0
# 125951          391.0            0.0      123.0             0.0
# 87817           201.0           22.0       17.0             0.0
# 42037           331.0           73.0       43.0             0.0
# ...               ...            ...        ...             ...
# 132929         9518.0          842.0     2427.0            38.0
# 251541          234.0            0.0       58.0             0.0
# 84057            97.0          721.0       13.0             0.0
# 32889           516.0            0.0      260.0             0.0
# 269836         2914.0           78.0     2205.0            75.0
#
#         late_aircraft_delay
# 256596               1916.0
# 6930                 1672.0
# 125951                 95.0
# 87817                  20.0
# 42037                 111.0
# ...                     ...
# 132929              21521.0
# 251541                 14.0
# 84057                 229.0
# 32889                 213.0
# 269836               2272.0
#
# [79317 rows x 17 columns]

# %%
y_pred = NewKerasModel.predict(X_test)
# Out:
# 2479/2479 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step

# %%
print('Prediction Shape is {}'.format(y_pred.shape))
# Out:
# Prediction Shape is (79317, 1)

# %%
print('Prediction items are {}'.format(y_pred[:5]))
# Out:
# Prediction items are [[9.9958956e-01]
#  [9.9908161e-01]
#  [2.1105802e-04]
#  [1.3487197e-04]
#  [2.0052331e-04]]

# %%
y_test[:5]
# Out:
# 256596    1
# 6930      1
# 125951    0
# 87817     0
# 42037     0
# Name: WDCase, dtype: int64

# %%
ModelLoss, ModelAccuracy = NewKerasModel.evaluate(X_test, y_test)
print('Model Loss is {}'.format(ModelLoss))
print('Model Accuracy is {}'.format(ModelAccuracy ))
# Out:
# 2479/2479 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9994 - loss: 0.0022
# Model Loss is 0.0022261107806116343
# Model Accuracy is 0.9993821978569031

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
len(y_test), len(y_pred)
# Out:
# (79317, 79317)

# %%
y_pred
# Out:
# array([[9.9958956e-01],
#        [9.9908161e-01],
#        [2.1105802e-04],
#        ...,
#        [9.9864286e-01],
#        [2.1105363e-04],
#        [4.1591088e-04]], dtype=float32)

# %%
y_pred = [np.round(i[0]) for i in y_pred]
y_pred
# Out:
# [np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(1.0),
#  np.float32(1.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  np.float32(0.0),
#  ...]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
CM = confusion_matrix(y_test, y_pred)
print('Confusion Matrix is : \n', CM)
# Out:
# Confusion Matrix is :
#  [[53682    42]
#  [    7 25586]]

# %%
# drawing confusion matrix
sns.heatmap(CM, center = True,cmap='Blues_r')
plt.show()

# %%
from sklearn.metrics import classification_report
ClassificationReport = classification_report(y_test,y_pred)
print('Classification Report is : \n', ClassificationReport )
# Out:
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     53724
#            1       1.00      1.00      1.00     25593
#
#     accuracy                           1.00     79317
#    macro avg       1.00      1.00      1.00     79317
# weighted avg       1.00      1.00      1.00     79317
